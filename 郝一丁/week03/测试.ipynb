# %% [markdown]
# ## RNN

# %%
from 文本分类 import train_text_classifier

predict, acc, artifacts = train_text_classifier(
    dataset_path="dataset.csv",
    model_type="rnn",   # "lstm" / "gru" / "rnn"
    num_epochs=10,
    verbose=False
)

print("acc =", acc)
print(predict("帮我导航到北京"))
# Out:
# acc = 0.13958677685950413
# Travel-Query

# %% [markdown]
# ## LSTM

# %%
from 文本分类 import train_text_classifier

predict, acc, artifacts = train_text_classifier(
    dataset_path="dataset.csv",
    model_type="lstm",   # "lstm" / "gru" / "rnn"
    num_epochs=10,
    verbose=False
)

print("acc =", acc)
print(predict("帮我导航到北京"))
# Out:
# acc = 0.9725619834710744
# Travel-Query

# %% [markdown]
# ## GRU

# %%
from 文本分类 import train_text_classifier

predict, acc, artifacts = train_text_classifier(
    dataset_path="dataset.csv",
    model_type="gru",   # "lstm" / "gru" / "rnn"
    num_epochs=10,
    verbose=False
)

print("acc =", acc)
print(predict("帮我导航到北京"))
# Out:
# acc = 0.9899173553719008
# Travel-Query
